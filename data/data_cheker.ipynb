# %%
import pandas as pd
df = pd.read_excel('icecontro2025pagoest.xlsx')

# %%
df
# Out:
#                                 CURSO               INICIO   FINALIZA  \
# 0    Rep. Equipos Elect. Y tarj. Dig.  2025-01-18 00:00:00 2025-02-22
# 1                                 NaN                  NaN        NaT
# 2                                 NaN                  NaN        NaT
# 3                                 NaN                  NaN        NaT
# 4                                 NaN                  NaN        NaT
# ..                                ...                  ...        ...
# 416                               NaN                  NaN        NaT
# 417                               NaN                  NaN        NaT
# 418                               NaN                  NaN        NaT
# 419                               NaN                  NaN        NaT
# 420                               NaN                  NaN        NaT
#
#         GRUPO        PROF                       PARTICIPANTES    TELEFONO  \
# ...
